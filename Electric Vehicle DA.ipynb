# %%
import pandas as pd

# %%
df=pd.read_csv(r"C:\Users\Admin\Downloads\Electric_Vehicle_Population_Data.csv\Electric_Vehicle_Population_Data.csv")
df
# Out:
#         VIN (1-10)     County            City State  Postal Code  Model Year  \
# 0       WBY8P6C58K       King         Seattle    WA      98115.0        2019
# 1       5YJSA1DN4D     Kitsap       Bremerton    WA      98312.0        2013
# 2       5YJSA1E26J       King            Kent    WA      98042.0        2018
# 3       WBY2Z2C54E       King        Bellevue    WA      98004.0        2014
# 4       5YJXCDE23J       King        Bellevue    WA      98004.0        2018
# ...            ...        ...             ...   ...          ...         ...
# 186874  JTMEB3FVXM  Snohomish       Arlington    WA      98223.0        2021
# 186875  7SAYGAEEXP  Snohomish        Stanwood    WA      98292.0        2023
# 186876  3FA6P0SUXK       King          Auburn    WA      98001.0        2019
# 186877  7SAYGDEE1P     Pierce          Tacoma    WA      98422.0        2023
# 186878  7SAYGDEE1R    Douglas  East Wenatchee    WA      98802.0        2024
#
# ...

# %%
#remove duplicates if any
df=df.drop_duplicates()
df
# Out:
#         VIN (1-10)     County            City State  Postal Code  Model Year  \
# 0       WBY8P6C58K       King         Seattle    WA      98115.0        2019
# 1       5YJSA1DN4D     Kitsap       Bremerton    WA      98312.0        2013
# 2       5YJSA1E26J       King            Kent    WA      98042.0        2018
# 3       WBY2Z2C54E       King        Bellevue    WA      98004.0        2014
# 4       5YJXCDE23J       King        Bellevue    WA      98004.0        2018
# ...            ...        ...             ...   ...          ...         ...
# 186874  JTMEB3FVXM  Snohomish       Arlington    WA      98223.0        2021
# 186875  7SAYGAEEXP  Snohomish        Stanwood    WA      98292.0        2023
# 186876  3FA6P0SUXK       King          Auburn    WA      98001.0        2019
# 186877  7SAYGDEE1P     Pierce          Tacoma    WA      98422.0        2023
# 186878  7SAYGDEE1R    Douglas  East Wenatchee    WA      98802.0        2024
#
# ...

# %%
#Renaming column name
df.columns=df.columns.str.replace('[\(\)0-9-]','',regex=True)
df.columns=df.columns.str.replace('\s$|^\s','',regex=True)
df.columns=df.columns.str.lower()
df.columns=df.columns.str.replace(' ','_')
df.columns
# Out:
# Index(['vin', 'county', 'city', 'state', 'postal_code', 'model_year', 'make',
#        'model', 'electric_vehicle_type',
#        'clean_alternative_fuel_vehicle_cafv_eligibility', 'electric_range',
#        'base_msrp', 'legislative_district', 'dol_vehicle_id',
#        'vehicle_location', 'electric_utility', 'census_tract'],
#       dtype='object')

# %%
#handling null value  
df.isna().sum()
# Out:
# vin                                                  0
# county                                               3
# city                                                 3
# state                                                0
# postal_code                                          3
# model_year                                           0
# make                                                 0
# model                                                0
# electric_vehicle_type                                0
# clean_alternative_fuel_vehicle_cafv_eligibility      0
# electric_range                                       0
# base_msrp                                            0
# legislative_district                               403
# dol_vehicle_id                                       0
# vehicle_location                                     8
# electric_utility                                     3
# census_tract                                         3
# dtype: int64

# %%
df[df['legislative_district'].isna()==1]
# Out:
#                vin      county           city state  postal_code  model_year  \
# 483     5YJ3E1EB9L      Denton     Little Elm    TX      75068.0        2020
# 491     5YJXCDE26L      Harris        Houston    TX      77002.0        2020
# 27486   JTMAB3FV4M   San Diego      Oceanside    CA      92057.0        2021
# 52770   5YJ3E1EB4L    New York       New York    NY      10010.0        2020
# 58353   7FCTGAAA2N    Monterey        Seaside    CA      93955.0        2022
# ...            ...         ...            ...   ...          ...         ...
# 184763  JTDKAMFP4N    Monterey  Pacific Grove    CA      93950.0        2022
# 185247  KNDCM3LD7K      Orange    Chapel Hill    NC      27516.0        2019
# 185764  KNDCC3LGXN  Alexandria     Alexandria    VA      22314.0        2022
# 186008  5YJ3E1EB2J     Suffolk        Suffolk    VA      23435.0        2018
# 186496  5YJ3E1EB3M       Clark      Las Vegas    NV      89135.0        2021
#
# ...

# %%
df=df.fillna(0)

# %%
df.isna().sum()
# Out:
# vin                                                0
# county                                             0
# city                                               0
# state                                              0
# postal_code                                        0
# model_year                                         0
# make                                               0
# model                                              0
# electric_vehicle_type                              0
# clean_alternative_fuel_vehicle_cafv_eligibility    0
# electric_range                                     0
# base_msrp                                          0
# legislative_district                               0
# dol_vehicle_id                                     0
# vehicle_location                                   0
# electric_utility                                   0
# census_tract                                       0
# dtype: int64

# %%
#drop the unwanted column
df.drop(columns=['model','census_tract','dol_vehicle_id','vehicle_location','electric_utility'],inplace=True)

# %%
#installing mysqlclient 
#!pip install mysqlclient

# %%
#connecting to mqlsql and loading dataset to db
from sqlalchemy import create_engine as ce
mysql_engine=ce("mysql://root:mysql123@localhost:3306/database2")
df.to_sql('electric_vehicle',mysql_engine)
# Out:
# 186879
